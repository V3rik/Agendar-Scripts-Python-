# %% [markdown]
# # Agendando tarefas em Python
#
# Por: Guilherme da Silva
#
# GitHub: @V3rik
#
# Youtube:

# %% [markdown]
# 1 - abra programa 'Agendador de tarefas'
#
# ![agendador%20de%20tarefas.png](attachment:agendador%20de%20tarefas.png)

# %% [markdown]
# 2- Após abrir o agendador de tarefas clique em 'Criar tarefa'
# ![criar%20nova%20tarfa.png](attachment:criar%20nova%20tarfa.png)

# %% [markdown]
# 3- Digite o nome e a descrição da tarefa
#
# ![digitar%20nome%20e%20descri%C3%A7%C3%A3o.png](attachment:digitar%20nome%20e%20descri%C3%A7%C3%A3o.png)

# %% [markdown]
# 3- especifique quando a tarefa será executada, se será todos os dias, ou ao ligar o computador
# ![especificar.png](attachment:especificar.png)

# %% [markdown]
# 4- vá para o campo ações e clique em novo.
#
# Note que há um campo escrito executavel do python, muita das vezes os problemas estão relacionados ao executavel do python, casp você tenha problema execute esse comando:
#
# ### inicio do comando
#
# import os
#
# import sys
#
# print(os.path.dirname(sys.executable))
#
#
# ### fim do comando
#
#
# OBS: esse comando apontará em qual pasta está o executavel do python
#
#
# ![1.png](attachment:1.png)

# %% [markdown]
# 5- Vamos no campo que está escrito 'Executavel do Python' e irémos colocar o arquivo executavel:
#
# ![exe%20python.png](attachment:exe%20python.png)

# %% [markdown]
# Veja como ficou ao adicionar o exe do python:
#
# ![final%20exe.png](attachment:final%20exe.png)

# %% [markdown]
# 6- Vamos agora digitar o campo que está escrito 'nome_arquivo.py'
#
#
# O nome do nosso arquivo é: automa_sp
#
#
# ![nome%20arquivo.png](attachment:nome%20arquivo.png)

# %% [markdown]
# veja como ficou após digitar o nome do arquivo:
#
#
# OBS: note que o arquivo deve ser = nome_arquivo.py (extenssão python)
#
#
# ![final%20nome%20arquivo.png](attachment:final%20nome%20arquivo.png)

# %% [markdown]
# 7- indicando o caminho do arquivo .py
#
#
# Basta copiar o diretório em que se encontra o arquivo .py
#
# ![caminh.png](attachment:caminh.png)

# %% [markdown]
# veja como ficou:
#
# ![final%20final.png](attachment:final%20final.png)

# %% [markdown]
# Agora clique em ok:
#
# após clique no botão oky de novo que a terafa estára salva
#
# ![ok%20d%20novo.png](attachment:ok%20d%20novo.png)

# %% [markdown]
# 8- A tarefa está salva agora clique em executar para ver se a mesma está funcionando:
#
#  ![tarefa%20salva.png](attachment:tarefa%20salva.png)
